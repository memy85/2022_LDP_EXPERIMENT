# %%
from pathlib import Path

bp_path = Path('/home/wonseok/2022_LDP_EXPERIMENT/data/raw/BP.feather')
rbc_path = Path('/home/wonseok/2022_LDP_EXPERIMENT/data/raw/RBC.feather')

lm_bp_path = Path('/home/wonseok/2022_LDP_EXPERIMENT/data/processed/lm_simulation/BP.feather')
lm_rbc_path = Path('/home/wonseok/2022_LDP_EXPERIMENT/data/processed/lm_simulation/RBC.feather')

new_lm_bp_path = Path('/home/wonseok/2022_LDP_EXPERIMENT/data/processed/new_lm_simulation/BP.feather')
new_lm_rbc_path = Path('/home/wonseok/2022_LDP_EXPERIMENT/data/processed/new_lm_simulation/RBC.feather')

# %%
import pandas as pd

bp = pd.read_feather(lm_bp_path)
rbc = pd.read_feather(lm_rbc_path)

# %%
rbc
# Out:
#          patientunitstayid  labresultoffset labname  value  value_0.1  \
# 0                  1572869               17     RBC   4.29   3.489355
# 1                  1572869             1278     RBC   3.02  45.146117
# 2                  1572869             2647     RBC   2.78   4.015214
# 3                  2097158            -1293     RBC   4.40   5.455348
# 4                  2097158             1065     RBC   3.81   5.336934
# ...                    ...              ...     ...    ...        ...
# 1107643            2097150             8575     RBC   3.42   2.900108
# 1107644            2097150             9265     RBC   3.39  10.777865
# 1107645            2097150            10040     RBC   3.53  -5.217574
# 1107646            2097150            10635     RBC   3.65   6.762031
# 1107647            2097150            11418     RBC   2.98  12.590038
#
#          value_0.2  value_0.4  value_0.8  value_1.6  value_3.2  value_6.4
# ...
